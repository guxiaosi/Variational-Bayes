# %%
#State Evoluation (second version fix the chi)
import numpy as np
import matplotlib.pyplot as plt
from numpy import linalg as LA

def y_s(p,t):#using iteration to solve y^*
    eps = 0.001 #epsilon
    y_st = 1 #initial y^*
    flag =True
    while flag:
        y_new = np.tanh(p+np.sqrt(t)*y_st)*np.sqrt(t)
        if LA.norm(y_new - y_st) < eps: #update until threshold met
            flag = False
            return y_new #return the solution
            break
        y_st = y_new

def F(p,t): #F function
    return y_s(p,t)/(np.sqrt(t))

def T(p,t): #T function
    return (1-F(p,t)**2)/(1-t*(1-F(p,t)**2))

def k_sigma(alpha):
    k_t = 1
    sigma_s2 = 1
    sigma_t2 = 10
    #alpha = 1
    lamb = 3
    chi = 0.3
    eps = 0.001
    parameter_old = np.array([k_t,sigma_t2])
    parameter_new = np.array([0,0])
    iter_ = 0
    mu = 0
    sigma = 1
    while LA.norm(parameter_new - parameter_old)>eps:
        parameter_old = np.array([k_t,sigma_t2])
        z = np.random.normal(mu,sigma,1000)
        sum_f = 0
        sum_f2 = 0
        for i in range(1000):
            sum_f +=F(k_t*sigma_s2+np.sqrt(k_t**2*sigma_s2+sigma_t2)*z[i],chi)
            sum_f2 += F(k_t*sigma_s2+np.sqrt(k_t**2*sigma_s2+sigma_t2)*z[i],chi)**2
        k_new = alpha*chi*sum_f/1000
        sigma_new = alpha*chi**2*sum_f2/1000
        parameter_new = np.array([k_new,sigma_new])
        k_t = k_new
        sigma_t2 = sigma_new
        iter_+=1
    return parameter_new

for alpha in np.arange(0.0,3.5,0.1):
    plt.scatter(alpha,k_sigma(alpha)[0],c="r")
plt.title("k_t and alpha (chi fixed at 0.3)")
plt.ylabel("k_t")
plt.xlabel("alpha")
plt.grid()
plt.show()

# %%
#State Evoluation (second version fix the chi)
import numpy as np
import matplotlib.pyplot as plt
from numpy import linalg as LA

def y_s(p,t):#using iteration to solve y^*
    eps = 0.001 #epsilon
    y_st = 1 #initial y^*
    flag =True
    while flag:
        y_new = np.tanh(p+np.sqrt(t)*y_st)*np.sqrt(t)
        if LA.norm(y_new - y_st) < eps: #update until threshold met
            flag = False
            return y_new #return the solution
            break
        y_st = y_new

def F(p,t): #F function
    return y_s(p,t)/(np.sqrt(t))

def T(p,t): #T function
    return (1-F(p,t)**2)/(1-t*(1-F(p,t)**2))

def k_sigma(alpha):
    k_t = 1
    sigma_s2 = 1
    sigma_t2 = 10
    #alpha = 1
    lamb = 3
    chi = 0.4
    eps = 0.01
    parameter_old = np.array([k_t,sigma_t2])
    parameter_new = np.array([0,0])
    iter_ = 0
    mu = 0
    sigma = 1
    while LA.norm(parameter_new - parameter_old)>eps:
        parameter_old = np.array([k_t,sigma_t2])
        z = np.random.normal(mu,sigma,1000)
        sum_f = 0
        sum_f2 = 0
        for i in range(1000):
            sum_f +=F(k_t*sigma_s2+np.sqrt(k_t**2*sigma_s2+sigma_t2)*z[i],chi)
            sum_f2 += F(k_t*sigma_s2+np.sqrt(k_t**2*sigma_s2+sigma_t2)*z[i],chi)**2
        k_new = alpha*chi*sum_f/1000
        sigma_new = alpha*chi**2*sum_f2/1000
        parameter_new = np.array([k_new,sigma_new])
        k_t = k_new
        sigma_t2 = sigma_new
        iter_+=1
    return parameter_new

for alpha in np.arange(0.0,3.5,0.1):
    plt.scatter(alpha,k_sigma(alpha)[0],c="b")
plt.title("k_t and alpha (chi fixed at 0.4)")
plt.ylabel("k_t")
plt.xlabel("alpha")
plt.grid()
plt.show()

# %%
#State Evoluation (second version fix alpha)
import numpy as np
import matplotlib.pyplot as plt
from numpy import linalg as LA

def y_s(p,t):#using iteration to solve y^*
    eps = 0.001 #epsilon
    y_st = 1 #initial y^*
    flag =True
    while flag:
        y_new = np.tanh(p+np.sqrt(t)*y_st)*np.sqrt(t)
        if LA.norm(y_new - y_st) < eps: #update until threshold met
            flag = False
            return y_new #return the solution
            break
        y_st = y_new

def F(p,t): #F function
    return y_s(p,t)/(np.sqrt(t))

def T(p,t): #T function
    return (1-F(p,t)**2)/(1-t*(1-F(p,t)**2))

def k_sigma(chi):
    k_t = 1
    sigma_s2 = 1
    sigma_t2 = 10
    alpha = 1.5
    lamb = 3
    #chi = 0.3
    eps = 0.01
    parameter_old = np.array([k_t,sigma_t2])
    parameter_new = np.array([0,0])
    iter_ = 0
    mu = 0
    sigma = 1
    while LA.norm(parameter_new - parameter_old)>eps:
        parameter_old = np.array([k_t,sigma_t2])
        z = np.random.normal(mu,sigma,1000)
        sum_f = 0
        sum_f2 = 0
        for i in range(1000):
            sum_f +=F(k_t*sigma_s2+np.sqrt(k_t**2*sigma_s2+sigma_t2)*z[i],chi)
            sum_f2 += F(k_t*sigma_s2+np.sqrt(k_t**2*sigma_s2+sigma_t2)*z[i],chi)**2
        k_new = alpha*chi*sum_f/1000
        sigma_new = alpha*chi**2*sum_f2/1000
        parameter_new = np.array([k_new,sigma_new])
        k_t = k_new
        sigma_t2 = sigma_new
        iter_+=1
    return parameter_new


for chi in np.arange(0.01,1,0.05):
    plt.scatter(chi,k_sigma(chi)[0],c="r")
    plt.scatter(chi,k_sigma(chi)[1],c="b")
plt.scatter(0,0,c="r",label="k_t")
plt.scatter(0,0,c="b",label="sigma_t2")
plt.title("k_t, sigma_t2 and chi (alpha fixed at 1.5)")
plt.ylabel("k_t, sigma_t2")
plt.xlabel("chi")
plt.legend()
plt.grid()
plt.show()

# %%
#State Evoluation (second version fix alpha)
import numpy as np
import matplotlib.pyplot as plt
from numpy import linalg as LA

def y_s(p,t):#using iteration to solve y^*
    eps = 0.001 #epsilon
    y_st = 1 #initial y^*
    flag =True
    while flag:
        y_new = np.tanh(p+np.sqrt(t)*y_st)*np.sqrt(t)
        if LA.norm(y_new - y_st) < eps: #update until threshold met
            flag = False
            return y_new #return the solution
            break
        y_st = y_new

def F(p,t): #F function
    return y_s(p,t)/(np.sqrt(t))

def T(p,t): #T function
    return (1-F(p,t)**2)/(1-t*(1-F(p,t)**2))

def k_sigma(chi):
    k_t = 1
    sigma_s2 = 1
    sigma_t2 = 10
    alpha = 0.5
    lamb = 3
    #chi = 0.3
    eps = 0.01
    parameter_old = np.array([k_t,sigma_t2])
    parameter_new = np.array([0,0])
    iter_ = 0
    mu = 0
    sigma = 1
    while LA.norm(parameter_new - parameter_old)>eps:
        parameter_old = np.array([k_t,sigma_t2])
        z = np.random.normal(mu,sigma,1000)
        sum_f = 0
        sum_f2 = 0
        for i in range(1000):
            sum_f +=F(k_t*sigma_s2+np.sqrt(k_t**2*sigma_s2+sigma_t2)*z[i],chi)
            sum_f2 += F(k_t*sigma_s2+np.sqrt(k_t**2*sigma_s2+sigma_t2)*z[i],chi)**2
        k_new = alpha*chi*sum_f/1000
        sigma_new = alpha*chi**2*sum_f2/1000
        parameter_new = np.array([k_new,sigma_new])
        k_t = k_new
        sigma_t2 = sigma_new
        iter_+=1
    return parameter_new


for chi in np.arange(0.01,1,0.05):
    plt.scatter(chi,k_sigma(chi)[0],c="r")
    plt.scatter(chi,k_sigma(chi)[1],c="b")
plt.scatter(0,0,c="r",label="k_t")
plt.scatter(0,0,c="b",label="sigma_t2")
plt.title("k_t, sigma_t2 and chi (alpha fixed at 0.5)")
plt.ylabel("k_t, sigma_t2")
plt.xlabel("chi")
plt.legend()
plt.grid()
plt.show()

# %%
#State Evoluation (second version fix the chi)
import numpy as np
import matplotlib.pyplot as plt
from numpy import linalg as LA

def y_s(p,t):#using iteration to solve y^*
    eps = 0.001 #epsilon
    y_st = 1 #initial y^*
    flag =True
    while flag:
        y_new = np.tanh(p+np.sqrt(t)*y_st)*np.sqrt(t)
        if LA.norm(y_new - y_st) < eps: #update until threshold met
            flag = False
            return y_new #return the solution
            break
        y_st = y_new

def F(p,t): #F function
    return y_s(p,t)/(np.sqrt(t))

def T(p,t): #T function
    return (1-F(p,t)**2)/(1-t*(1-F(p,t)**2))

def k_sigma(alpha):
    k_t = 1
    sigma_s2 = 1
    sigma_t2 = 10
    #alpha = 1
    lamb = 3
    chi = 0.3
    eps = 0.001
    parameter_old = np.array([k_t,sigma_t2])
    parameter_new = np.array([0,0])
    iter_ = 0
    mu = 0
    sigma = 1
    while LA.norm(parameter_new - parameter_old)>eps:
        parameter_old = np.array([k_t,sigma_t2])
        z = np.random.normal(mu,sigma,1000)
        sum_f = 0
        sum_f2 = 0
        for i in range(1000):
            sum_f +=F(k_t*sigma_s2+np.sqrt(k_t**2*sigma_s2+sigma_t2)*z[i],chi)
            sum_f2 += F(k_t*sigma_s2+np.sqrt(k_t**2*sigma_s2+sigma_t2)*z[i],chi)**2
        k_new = alpha*chi*sum_f/1000
        plt.scatter(iter_,k_new,c="b")
        sigma_new = alpha*chi**2*sum_f2/1000
        plt.scatter(iter_,sigma_new,c="r")
        parameter_new = np.array([k_new,sigma_new])
        k_t = k_new
        sigma_t2 = sigma_new
        iter_+=1
    plt.scatter(iter_,k_new,c="b",label="k_t")
    plt.scatter(iter_,sigma_new,c="r",label="sigma_t2")
    return parameter_new
k_sigma(3)
plt.title("k_t,sigma_t2 and t (chi fixed at 0.3), alpha = 3")
plt.ylabel("k_t,sigma_t2")
plt.xlabel("t")
plt.grid()
plt.legend()
plt.show()

# %%
#State Evoluation (second version fix the chi)
import numpy as np
import matplotlib.pyplot as plt
from numpy import linalg as LA

def y_s(p,t):#using iteration to solve y^*
    eps = 0.001 #epsilon
    y_st = 1 #initial y^*
    flag =True
    while flag:
        y_new = np.tanh(p+np.sqrt(t)*y_st)*np.sqrt(t)
        if LA.norm(y_new - y_st) < eps: #update until threshold met
            flag = False
            return y_new #return the solution
            break
        y_st = y_new

def F(p,t): #F function
    return y_s(p,t)/(np.sqrt(t))

def T(p,t): #T function
    return (1-F(p,t)**2)/(1-t*(1-F(p,t)**2))

def k_sigma(alpha):
    k_t = 1
    sigma_s2 = 1
    sigma_t2 = 10
    #alpha = 1
    lamb = 3
    chi = 0.3
    eps = 0.001
    parameter_old = np.array([k_t,sigma_t2])
    parameter_new = np.array([0,0])
    iter_ = 0
    mu = 0
    sigma = 1
    while LA.norm(parameter_new - parameter_old)>eps:
        parameter_old = np.array([k_t,sigma_t2])
        z = np.random.normal(mu,sigma,1000)
        sum_f = 0
        sum_f2 = 0
        for i in range(1000):
            sum_f +=F(k_t*sigma_s2+np.sqrt(k_t**2*sigma_s2+sigma_t2)*z[i],chi)
            sum_f2 += F(k_t*sigma_s2+np.sqrt(k_t**2*sigma_s2+sigma_t2)*z[i],chi)**2
        k_new = alpha*chi*sum_f/1000
        plt.scatter(iter_,k_new,c="b")
        sigma_new = alpha*chi**2*sum_f2/1000
        plt.scatter(iter_,sigma_new,c="r")
        parameter_new = np.array([k_new,sigma_new])
        k_t = k_new
        sigma_t2 = sigma_new
        iter_+=1
    plt.scatter(iter_,k_new,c="b",label="k_t")
    plt.scatter(iter_,sigma_new,c="r",label="sigma_t2")
    return parameter_new
k_sigma(1)
plt.title("k_t,sigma_t2 and t (chi fixed at 0.3), alpha = 1")
plt.ylabel("k_t,sigma_t2")
plt.xlabel("t")
plt.grid()
plt.legend()
plt.show()
